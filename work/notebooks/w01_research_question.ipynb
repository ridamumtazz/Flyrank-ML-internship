# %% [markdown]
# <a href="https://colab.research.google.com/github/ridamumtazz/Flyrank-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# ## 1. My lane (or freestyle) and why
#
# I am choosing the **Ranking/Scoring lane**. My question is: **Which content items should a content or SEO team prioritize for improvement first?** I chose this lane because a team may have many content items but limited time, so they need a useful way to decide what to work on first. The goal is not just to predict a number, but to create a priority score or ranked list that can support better decisions about where to spend editing and optimization effort. I will use the available content and performance data to look for patterns that can help rank items by priority.
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which content item should be prioritized for improvement first?
#
# **Who acts:** A content editor or SEO team member.
#
# **Action:** They can review and optimize the highest-priority content items first.
#
# **Cost of a wrong recommendation:** The team may waste time working on a low-value item and miss the opportunity to improve a more important item.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains **30,000 content items across 32 clients and 44 columns**. The median number of impressions over 90 days is **731**, while the average is **5,200.37**. Also, **16,262 out of 30,000 content items** have a `down` trend direction. These numbers make the ranking/scoring lane worth exploring because a team with many content items may need help deciding which items should receive attention first.

# %%
import pandas as pd

df = pd.read_csv("/content/Flyrank-ML-internship/data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Number of clients:", df["client_id"].nunique())

print("Average impressions:", df["impressions_90d"].mean())
print("Median impressions:", df["impressions_90d"].median())

print("Average CTR:", df["ctr"].mean())
print("Median CTR:", df["ctr"].median())

print("\nTrend direction:")
print(df["trend_direction"].value_counts())
# Out:
# Number of rows: 30000
# Number of columns: 44
# Number of clients: 32
# Average impressions: 5200.3663
# Median impressions: 731.0
# Average CTR: 0.5107333333333334
# Median CTR: 0.07
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work will provide **decision support** by using the available data to rank or prioritize content items. I may identify patterns in the data that can help a content or SEO team decide where to investigate first.
#
# I cannot claim that my work proves that one change causes better performance. I also cannot claim that it predicts Google's decisions or future search rankings with certainty. The results will depend on the available data and its limitations.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
