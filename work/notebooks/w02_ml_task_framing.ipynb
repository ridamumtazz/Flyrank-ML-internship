# %% [markdown]
# <a href="https://colab.research.google.com/github/ridamumtazz/Flyrank-ML-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### ML Task Type: Classification

I chose **classification** because the goal is to predict whether a webpage is likely to perform well or not based on its available features. The output is a category (high-performing or low-performing), not a continuous value.
"""))
# Out:
# ### ML Task Type: Classification
#
# I chose **classification** because the goal is to predict whether a webpage is likely to perform well or not based on its available features. The output is a category (high-performing or low-performing), not a continuous value.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Target

The target is to predict whether a webpage is high-performing or low-performing. The label comes from the observed data and performance metrics available in the dataset.
"""))
# Out:
# ### Target
#
# The target is to predict whether a webpage is high-performing or low-performing. The label comes from the observed data and performance metrics available in the dataset.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Success Metric

Precision@50 is an appropriate success metric because it measures how many of the top predicted pages are actually relevant or successful. A higher Precision@50 means better predictions.
"""))
# Out:
# ### Success Metric
#
# Precision@50 is an appropriate success metric because it measures how many of the top predicted pages are actually relevant or successful. A higher Precision@50 means better predictions.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

sample = pd.DataFrame({
    "url": ["https://example.com/page1"],
    "clicks": [320],
    "impressions": [5400],
    "ctr": [5.93],
    "avg_position": [8.4]
})

sample
# Out:
#                          url  clicks  impressions   ctr  avg_position
# 0  https://example.com/page1     320         5400  5.93           8.4

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Why Machine Learning?

A fixed rule cannot capture all the complex relationships between webpage features such as clicks, impressions, CTR, and average position. Machine learning can learn these patterns automatically and make better predictions than a simple if-else rule.
"""))
# Out:
# ### Why Machine Learning?
#
# A fixed rule cannot capture all the complex relationships between webpage features such as clicks, impressions, CTR, and average position. Machine learning can learn these patterns automatically and make better predictions than a simple if-else rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
