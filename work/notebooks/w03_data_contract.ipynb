# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Unit of Analysis

One row represents one webpage and its performance metrics over a selected monthly time window. The model uses these webpage-level observations to classify whether a page is high-performing or low-performing.
"""))
# Out:
# ### Unit of Analysis
#
# One row represents one webpage and its performance metrics over a selected monthly time window. The model uses these webpage-level observations to classify whether a page is high-performing or low-performing.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Fields

**Features**
- Clicks
- Impressions
- CTR
- Average Position
- Page Age

**Label**
- High-performing or Low-performing webpage

**Context**
- Monthly performance data
- Webpage URL

**Excluded**
- Client names and private information, because they are not useful for prediction and should remain confidential.
"""))
# Out:
# ### Fields
#
# **Features**
# - Clicks
# - Impressions
# - CTR
# - Average Position
# - Page Age
#
# **Label**
# - High-performing or Low-performing webpage
#
# **Context**
# - Monthly performance data
# - Webpage URL
#
# **Excluded**
# - Client names and private information, because they are not useful for prediction and should remain confidential.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd

df = pd.DataFrame({
    "url": ["page1", "page2", "page3"],
    "clicks": [320, 180, 90],
    "impressions": [5400, 3200, 1800],
    "ctr": [5.9, 5.6, 5.0],
    "avg_position": [8.4, 11.2, 18.6]
})

print("Rows:", len(df))
print("Missing values:")
print(df.isnull().sum())
print("\nData types:")
print(df.dtypes)
# Out:
# Rows: 3
# Missing values:
# url             0
# clicks          0
# impressions     0
# ctr             0
# avg_position    0
# dtype: int64
#
# Data types:
# url              object
# clicks            int64
# impressions       int64
# ctr             float64
# avg_position    float64
# dtype: object

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Data Limits

This dataset only contains historical webpage performance. It cannot explain why a webpage performed well, future user behavior, or external factors such as marketing campaigns or search engine algorithm updates.
"""))
# Out:
# ### Data Limits
#
# This dataset only contains historical webpage performance. It cannot explain why a webpage performed well, future user behavior, or external factors such as marketing campaigns or search engine algorithm updates.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
